# %%
import matplotlib
import matplotlib.pyplot as plt
#PLOTTING STATISTICS
peak = [1430,1254,2798,2554,3823,6201,5522]
reach = [0,44991,99627,165152,227690,278374,341628]

import matplotlib.pyplot as plt
#plt.plot(reach, dischmean, linewidth=2.0,label="mean discharge")
#plt.plot(reach,dischstdev, linewidth=2.0,label="standard deviation discharge")
#plt.plot(reach,dischmin, linewidth=2.0,label="minimum discharge")
plt.style.use('classic')
plt.title("Peak Discharge - Hurricane Camille (1969)")
plt.plot(reach,peak, linewidth=1,label="maximum discharge")
plt.legend( loc='upper left')
plt.ylabel('Peak Discharge - CMS')
plt.xlabel('Downstream Distance - m')
plt.show()
